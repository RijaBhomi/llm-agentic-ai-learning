# %%
import google.generativeai as genai
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_732\613638648.py:1: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   import google.generativeai as genai

# %%
genai.configure(api_key= "AIzaSyDPzNoyUfcPs11GC5SSjYwFBgoNtbfF1uc")

# %%
model= genai.GenerativeModel('gemini-2.5-flash')
response = model.generate_content(
    "Explain transformers simply"
)

print(response.text)
# Out:
# Imagine you're reading a long, complex sentence, like:
#
# "The animal didn't cross the street because **it** was too tired."
#
# As a human, you immediately know that "it" refers to "the animal." How do you do that? You pay **attention** to the context, specifically connecting "it" back to "the animal."
#
# **Transformers are a type of neural network model designed to do exactly that, but for machines, on a massive scale.**
#
# Here's the simple breakdown:
#
# 1.  **The Problem They Solve:**
#     Before Transformers, AI models (like RNNs) processed text word by word. This was like having a very short-term memory. By the time they got to "it" in our example, they might have forgotten what "animal" was, especially in longer sentences. They struggled to understand context over long distances.
#
# 2.  **The Big Idea: "Attention" (The Game Changer)**
#     *   **Instead of reading word-by-word sequentially, a Transformer looks at *all* the words in a sentence at once.**
#     *   For every single word it's processing, it asks: "How much does every other word in this sentence relate to or help me understand *this* word?"
#     *   It then assigns an "attention score" or "weight" to how important each other word is. So, when it sees "it," it gives a high attention score to "animal," helping it understand the connection.
#     *   This is like having a mental highlighter that lights up relevant words as it processes each one, constantly cross-referencing for context.
#
# 3.  **Key Advantages:**
#     *   **Long-Range Context:** Because it looks at everything at once, it can understand relationships between words that are far apart in a sentence or even across paragraphs.
#     *   **Parallel Processing:** Since it doesn't have to process words one after another, it can process many parts of a sentence simultaneously, making it much faster and more efficient for training on huge amounts of data.
#     *   **Positional Encoding:** Since "attention" makes all words "see" each other equally, Transformers also have a clever way to encode the *order* of words (called positional encoding) so they don't lose the grammatical structure.
#
# **In essence, a Transformer is like a super-smart reader that doesn't just read words sequentially but constantly cross-references every word with every other word to build a rich understanding of the entire text.**
#
# This breakthrough ability to understand context over long distances is why Transformers power many of today's most impressive AI applications, including:
# *   ChatGPT and other large language models
# *   Machine translation (like Google Translate)
# *   Text summarization
# *   And much more!

# %%
user_input = input("Type your prompt here: ")

# %%
response = model.generate_content(user_input)
print(response.text)
